# %%
package VehicleUsages {
	doc
	/*
	 * Example usages of elements from the vehicle definitions model.
	 */

	import SI::N;
	import SI::m;
	import VehicleDefinitions::*;
	import ScalarFunctions::*;

	/* VALUES */	 
	T1 = 10.0 [N * m];
	T2 = 20.0 [N * m];
	
	/* PARTS */	
	part narrowRimWheel: Wheel {
		doc /* Narrow-rim wheel configuration with 4 to 5 lugbolts. */

		part lugbolt: Lugbolt[4..5];
	}
	
	part wideRimWheel: Wheel {
		doc /* Wide-rim wheel configuration with 4 to 6 lugbolts. */	

		part lugbolt: Lugbolt[4..6];
	}

	part vehicle_C1: Vehicle {
		doc /* Basic Vehicle configuration showing a part hierarchy. */

		part frontAxleAssembly: AxleAssembly {
			part frontWheel[2] subsets narrowRimWheel {
				part redefines lugbolt[4] {
					attribute redefines tighteningTorque = T1;
				}
			}
			part frontAxle: Axle;
		}		
		part rearAxleAssembly: AxleAssembly {
			part rearWheel[2] subsets wideRimWheel {
				part redefines lugbolt[6] {
					attribute redefines tighteningTorque = T2;
				}
			}
			part rearAxle: Axle;			
		}
	}
	
	part vehicle_C2 subsets vehicle_C1 {
		doc /* Specialized configuration with part-specific ports. */

		part redefines frontAxleAssembly {
			part leftFrontWheel subsets frontWheel = frontWheel#(1);
			part rightFrontWheel subsets frontWheel = frontWheel#(2);
			
			interface leftFrontMount: Mounting connect 
				frontAxle.leftMountingPoint to leftFrontWheel.hub;
				
			interface rightFrontMount: Mounting connect 
				frontAxle.rightMountingPoint to rightFrontWheel.hub;
		}
		
		part rearAxleAssembly redefines vehicle_C1::rearAxleAssembly {
			part leftRearWheel subsets rearWheel = rearWheel#(1);
			part rightRearWheel subsets rearWheel = rearWheel#(2);

			interface leftRearMount: Mounting connect 
				rearAxle.leftMountingPoint to leftRearWheel.hub;
				
			interface rightRearMount: Mounting connect 
				rearAxle.rightMountingPoint to rightRearWheel.hub;
		}		
	}
	
	part vehicle_C3 subsets vehicle_C2 {
		doc /* Further specialized configuration with a connection to a deeply-nested port. */

		
		part transmission: Transmission {
			port drive: ~DriveIF;
		}
		
		part redefines rearAxleAssembly {
			part redefines rearAxle {
				port drive: DriveIF;
			}
		}
		
		interface driveShaft connect 
			transDrive ::> transmission.drive to axleDrive ::> rearAxleAssembly.rearAxle.drive {
			flow transDrive.driveTorque to axleDrive.driveTorque;
		}		
	}
}
# Out:
# ERROR:Couldn't resolve reference to Namespace 'VehicleDefinitions'. (1.sysml line : 9 column : 9)
# ERROR:Couldn't resolve reference to Type 'Wheel'. (1.sysml line : 17 column : 23)
# ERROR:Couldn't resolve reference to Type 'Lugbolt'. (1.sysml line : 20 column : 17)
# ERROR:Couldn't resolve reference to Type 'Wheel'. (1.sysml line : 23 column : 21)
# ERROR:Couldn't resolve reference to Type 'Lugbolt'. (1.sysml line : 26 column : 17)
# ERROR:Couldn't resolve reference to Type 'Vehicle'. (1.sysml line : 29 column : 19)
# ERROR:Couldn't resolve reference to Type 'AxleAssembly'. (1.sysml line : 32 column : 27)
# ERROR:Couldn't resolve reference to Feature 'tighteningTorque'. (1.sysml line : 35 column : 26)
# ERROR:Couldn't resolve reference to Type 'Axle'. (1.sysml line : 38 column : 20)
# ERROR:Couldn't resolve reference to Type 'AxleAssembly'. (1.sysml line : 40 column : 26)
# ERROR:Couldn't resolve reference to Feature 'tighteningTorque'. (1.sysml line : 43 column : 26)
# ERROR:Couldn't resolve reference to Type 'Axle'. (1.sysml line : 46 column : 19)
# ERROR:Couldn't resolve reference to Type 'Mounting'. (1.sysml line : 57 column : 30)
# ERROR:Couldn't resolve reference to Feature 'leftMountingPoint'. (1.sysml line : 58 column : 15)
# ERROR:Couldn't resolve reference to Feature 'hub'. (1.sysml line : 58 column : 51)
# ERROR:Couldn't resolve reference to Type 'Mounting'. (1.sysml line : 60 column : 31)
# ERROR:Couldn't resolve reference to Feature 'rightMountingPoint'. (1.sysml line : 61 column : 15)
# ERROR:Couldn't resolve reference to Feature 'hub'. (1.sysml line : 61 column : 53)
# ERROR:Couldn't resolve reference to Type 'Mounting'. (1.sysml line : 68 column : 29)
# ERROR:Couldn't resolve reference to Feature 'leftMountingPoint'. (1.sysml line : 69 column : 14)
# ERROR:Couldn't resolve reference to Feature 'hub'. (1.sysml line : 69 column : 49)
# ERROR:Couldn't resolve reference to Type 'Mounting'. (1.sysml line : 71 column : 30)
# ERROR:Couldn't resolve reference to Feature 'rightMountingPoint'. (1.sysml line : 72 column : 14)
# ERROR:Couldn't resolve reference to Feature 'hub'. (1.sysml line : 72 column : 51)
# ERROR:Couldn't resolve reference to Type 'Transmission'. (1.sysml line : 80 column : 22)
# ERROR:Couldn't resolve reference to ConjugatedPortDefinition '~DriveIF'. (1.sysml line : 81 column : 16)
# ERROR:Couldn't resolve reference to Type 'DriveIF'. (1.sysml line : 86 column : 17)
# ERROR:Couldn't resolve reference to Feature 'driveTorque'. (1.sysml line : 92 column : 20)
# ERROR:Couldn't resolve reference to Feature 'driveTorque'. (1.sysml line : 92 column : 45)
# ERROR:A part must be typed by item definitions. (1.sysml line : 17 column : 2)
# ERROR:A part must be typed by item definitions. (1.sysml line : 20 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 23 column : 2)
# ERROR:A part must be typed by item definitions. (1.sysml line : 26 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 29 column : 2)
# ERROR:A part must be typed by item definitions. (1.sysml line : 32 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 33 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 34 column : 5)
# ERROR:A part must be typed by item definitions. (1.sysml line : 38 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 40 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 41 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 42 column : 5)
# ERROR:A part must be typed by item definitions. (1.sysml line : 46 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 50 column : 2)
# ERROR:A part must be typed by item definitions. (1.sysml line : 53 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 54 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 55 column : 4)
# ERROR:An interface must be typed by interface definitions. (1.sysml line : 57 column : 4)
# ERROR:An interface must be typed by interface definitions. (1.sysml line : 60 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 64 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 65 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 66 column : 4)
# ERROR:An interface must be typed by interface definitions. (1.sysml line : 68 column : 4)
# ERROR:An interface must be typed by interface definitions. (1.sysml line : 71 column : 4)
# ERROR:A part must be typed by item definitions. (1.sysml line : 76 column : 2)
# ERROR:A part must be typed by item definitions. (1.sysml line : 80 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 84 column : 3)
# ERROR:A part must be typed by item definitions. (1.sysml line : 85 column : 4)
# ERROR:A port must be typed by port definitions. (1.sysml line : 86 column : 5)
# ERROR:A port must be typed by port definitions. (1.sysml line : 91 column : 41)
